# %% [markdown]
# # week2. working with Pandas
#     Cognitive Systems for Health Techonology Application
#     26.1.2018
#     Thi Le Thanh
#     Helsinki Metropolia University of Applied Sciences

# %%
# Import libraries
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd

# %%
# Location of the dataset
filename = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.switzerland.data'

# Column names for the data
colnames = ['age',
            'sex',
            'cp',
            'trestbps',
            'chol',
            'fbs',
            'restecg',
            'thalach',
            'exang',
            'oldpeak',
            'slope',
            'ca',
            'thal',
            'num']

# Read data to data frame
df = pd.read_csv(filename, 
                 names = colnames, 
                 na_values = '?')

# Show first 5 rows
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   32    1   1      95.0     0  NaN      0.0    127.0    0.0      0.7    1.0
# 1   34    1   4     115.0     0  NaN      NaN    154.0    0.0      0.2    1.0
# 2   35    1   4       NaN     0  NaN      0.0    130.0    1.0      NaN    NaN
# 3   36    1   4     110.0     0  NaN      0.0    125.0    1.0      1.0    2.0
# 4   38    0   4     105.0     0  NaN      0.0    166.0    0.0      2.8    1.0
#
#    ca  thal  num
# 0 NaN   NaN    1
# 1 NaN   NaN    1
# 2 NaN   7.0    3
# 3 NaN   6.0    1
# 4 NaN   NaN    2

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 118   70    1   4     115.0     0  0.0      1.0     92.0    1.0      0.0
# 119   70    1   4     140.0     0  1.0      0.0    157.0    1.0      2.0
# 120   72    1   3     160.0     0  NaN      2.0    114.0    0.0      1.6
# 121   73    0   3     160.0     0  0.0      1.0    121.0    0.0      0.0
# 122   74    1   2     145.0     0  NaN      1.0    123.0    0.0      1.3
#
#      slope   ca  thal  num
# 118    2.0  NaN   7.0    1
# 119    2.0  NaN   7.0    3
# 120    2.0  2.0   NaN    0
# 121    1.0  NaN   3.0    1
# 122    1.0  NaN   NaN    1

# %%
df.mean() #df.std, df.min, df.max, df.count, df.median, df.mode
# Out:
# age          55.317073
# sex           0.918699
# cp            3.699187
# trestbps    130.206612
# chol          0.000000
# fbs           0.104167
# restecg       0.360656
# thalach     121.557377
# exang         0.442623
# oldpeak       0.653846
# slope         1.801887
# ca            1.600000
# thal          5.788732
# num           1.804878
# dtype: float64

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps   chol        fbs  \
# count  123.000000  123.000000  123.000000  121.000000  123.0  48.000000
# mean    55.317073    0.918699    3.699187  130.206612    0.0   0.104167
# std      9.032108    0.274414    0.688726   22.559151    0.0   0.308709
# min     32.000000    0.000000    1.000000   80.000000    0.0   0.000000
# 25%     51.000000    1.000000    4.000000  115.000000    0.0   0.000000
# 50%     56.000000    1.000000    4.000000  125.000000    0.0   0.000000
# 75%     61.500000    1.000000    4.000000  145.000000    0.0   0.000000
# max     74.000000    1.000000    4.000000  200.000000    0.0   1.000000
#
#           restecg     thalach       exang     oldpeak       slope        ca  \
# count  122.000000  122.000000  122.000000  117.000000  106.000000  5.000000
# mean     0.360656  121.557377    0.442623    0.653846    1.801887  1.600000
# std      0.590077   25.977438    0.498745    1.056061    0.623658  0.547723
# ...

# %%
df['age'].plot()
plt.xlabel('Index')
plt.ylabel ('Age (Years)')
plt.grid()
plt.show()

# %%
df['age'].hist()
plt.xlabel ('Age (Years)')
plt.ylabel ('Count')
plt.show()

# %%
df['age'].hist(bins = np.arange(30,100,5))
plt.xlabel ('Age (Years)')
plt.ylabel ('Count')
plt.show()

# %%
df['age'].plot.box()

# %%
df.boxplot(column='age', by='sex')
# Out:
# C:\Users\thilet\AppData\Local\conda\conda\envs\my_root\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
df.plot.scatter('age', 'trestbps', c = 'num')
plt.xlabel('Age')
plt.ylabel('tresbps')
plt.title('Scatterogram of tresbps vs. age')
plt.show()

# %%
# Checking to correlation between attributes
df.corr()
# Out:
#                age       sex        cp  trestbps  chol       fbs   restecg  \
# age       1.000000 -0.049042 -0.033295  0.360333   NaN  0.120893  0.274539
# sex      -0.049042  1.000000  0.043017 -0.086998   NaN  0.061236  0.080047
# cp       -0.033295  0.043017  1.000000 -0.021996   NaN  0.090275 -0.237887
# trestbps  0.360333 -0.086998 -0.021996  1.000000   NaN  0.101617  0.187160
# chol           NaN       NaN       NaN       NaN   NaN       NaN       NaN
# fbs       0.120893  0.061236  0.090275  0.101617   NaN  1.000000  0.014847
# restecg   0.274539  0.080047 -0.237887  0.187160   NaN  0.014847  1.000000
# thalach  -0.284421 -0.121867 -0.056512 -0.207991   NaN  0.037192  0.008631
# exang    -0.033004  0.083337  0.268548  0.126132   NaN -0.016187 -0.120658
# oldpeak   0.145756 -0.054039  0.162727  0.081507   NaN  0.035405 -0.091993
# slope     0.077348 -0.036262  0.054803 -0.100769   NaN  0.060567 -0.059467
# ...

# %%
# see: https://pandas.pydata.org/pandas-docs/stable/visualization.html#box-plots
# see: https://pandas.pydata.org/pandas-docs/stable/visualization.html#scatter-matrix-plot
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize = (20, 20));
# Out:
# C:\Users\thilet\AppData\Local\conda\conda\envs\my_root\lib\site-packages\matplotlib\axes\_base.py:2918: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\thilet\AppData\Local\conda\conda\envs\my_root\lib\site-packages\matplotlib\axes\_base.py:3239: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.0, top=0.0
#   'bottom=%s, top=%s') % (bottom, top))

# %%
# Replace the missing value with the most common values, 
#( at least need to do something with missing value)
df = df.where(~np.isnan(df), df.mode(), axis = 'columns')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   32    1   1      95.0     0  0.0      0.0    127.0    0.0      0.7    1.0
# 1   34    1   4     115.0     0  0.0      0.0    154.0    0.0      0.2    1.0
# 2   35    1   4     115.0     0  0.0      0.0    130.0    1.0      0.0    2.0
# 3   36    1   4     110.0     0  0.0      0.0    125.0    1.0      1.0    2.0
# 4   38    0   4     105.0     0  0.0      0.0    166.0    0.0      2.8    1.0
#
#     ca  thal  num
# 0  2.0   7.0    1
# 1  2.0   7.0    1
# 2  2.0   7.0    3
# 3  2.0   6.0    1
# 4  2.0   7.0    2

# %%
df.mode()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   61    1   4     115.0     0  0.0      0.0    120.0    0.0      0.0    2.0
#
#     ca  thal  num
# 0  2.0   7.0    1

# %%
# Output value: 0= normal, 1= heart disease
label = df['num'] > 0
label.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: num, dtype: bool

# %%
# Check if there is some missing value
y = label.values
y
# Out:
# array([ True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True], dtype=bool)

# %%
# Scale the attributes arcoding to goal of network 
#classify between disease or not disease (1-0), using min and max 
#have another goal, another scaling
x = df['age']
(x - x.min())/(x.max()-x.min())
# Out:
# 0      0.000000
# 1      0.047619
# 2      0.071429
# 3      0.095238
# 4      0.142857
# 5      0.142857
# 6      0.142857
# 7      0.142857
# 8      0.142857
# 9      0.142857
# 10     0.190476
# 11     0.214286
# 12     0.238095
# 13     0.238095
# 14     0.261905
# 15     0.261905
# 16     0.261905
# 17     0.309524
# 18     0.333333
# 19     0.333333
# 20     0.357143
# 21     0.357143
# 22     0.357143
# 23     0.357143
# 24     0.380952
# 25     0.428571
# 26     0.428571
# 27     0.428571
# 28     0.428571
# 29     0.452381
#          ...
# 93     0.714286
# 94     0.714286
# 95     0.714286
# 96     0.714286
# 97     0.714286
# 98     0.714286
# 99     0.738095
# 100    0.738095
# 101    0.738095
# 102    0.738095
# 103    0.738095
# 104    0.761905
# 105    0.761905
# 106    0.761905
# 107    0.785714
# 108    0.785714
# 109    0.785714
# 110    0.785714
# 111    0.809524
# 112    0.809524
# 113    0.833333
# 114    0.857143
# 115    0.857143
# 116    0.880952
# ...

# %%
# Scale the whole data
df2 = (df-df.min())/(df.max()-df.min())
df2['chol'] = 0 #Cholesterol values were originlly all zeros
df2.head()
# Out:
#         age  sex   cp  trestbps  chol  fbs  restecg   thalach  exang  \
# 0  0.000000  1.0  0.0  0.125000     0  0.0      0.0  0.549180    0.0
# 1  0.047619  1.0  1.0  0.291667     0  0.0      0.0  0.770492    0.0
# 2  0.071429  1.0  1.0  0.291667     0  0.0      0.0  0.573770    1.0
# 3  0.095238  1.0  1.0  0.250000     0  0.0      0.0  0.532787    1.0
# 4  0.142857  0.0  1.0  0.208333     0  0.0      0.0  0.868852    0.0
#
#     oldpeak  slope   ca  thal   num
# 0  0.523810    0.0  1.0  1.00  0.25
# 1  0.444444    0.0  1.0  1.00  0.25
# 2  0.412698    0.5  1.0  1.00  0.75
# 3  0.571429    0.5  1.0  0.75  0.25
# 4  0.857143    0.0  1.0  1.00  0.50

# %%
# Select all attributes that were measured without angiography
colums = ['age',
            'sex',
            'cp',
            'trestbps',
            'chol',
            'fbs',
            'restecg',
            'thalach',
            'exang',
            'oldpeak',
            'slope']
data = df2[colums].values   # Convert the data to numpy array

# %%
# Now you are ready to use the labels and data for neural networks!
